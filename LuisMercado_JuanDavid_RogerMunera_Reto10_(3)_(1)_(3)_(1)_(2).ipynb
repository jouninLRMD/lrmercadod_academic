# %% [markdown]
# <a href="https://colab.research.google.com/github/jouninLRMD/lrmercadod_academic/blob/master/LuisMercado_JuanDavid_RogerMunera_Reto10_(3)_(1)_(3)_(1)_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Reto 10.**
# Re conectados.
#
# Luís mercado
#
# Juan David
#
# Roger A. Múnera P

# %% [markdown]
# Importación de Numpy, Pandas y archivo homicide.

# %%
import numpy as np
import pandas as pd
#Data import

df=pd.read_csv('/content/Homicide.csv')

# %%
df.info()  # Noción primaria de la naturaleza de los datos.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638454 entries, 0 to 638453
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Record ID              638454 non-null  int64
#  1   Agency Code            638454 non-null  object
#  2   Agency Name            638454 non-null  object
#  3   Agency Type            638454 non-null  object
#  4   City                   638454 non-null  object
#  5   State                  638454 non-null  object
#  6   Year                   638454 non-null  int64
#  7   Month                  638454 non-null  object
#  8   Incident               638454 non-null  int64
#  9   Crime Type             638454 non-null  object
#  10  Crime Solved           638454 non-null  object
#  11  Victim Sex             638454 non-null  object
#  12  Victim Age             638454 non-null  int64
#  13  Victim Race            638454 non-null  object
# ...

# %% [markdown]
# El FBI lo contrata para realizar un proceso de análisis exploratorio científico sobre un histórico de homicidios reales en Estados Unidos, del cual desea conocer la siguiente información:

# %% [markdown]
# **1. Listar las cinco primeras ciudades con el mayor número de agencias.**

# %%
df['Agency Type'].value_counts().sort_values(ascending=False)
# Out:
# Municipal Police    493026
# Sheriff             105322
# County Police        22693
# State Police         14235
# Special Police        2889
# Regional Police        235
# Tribal Police           54
# Name: Agency Type, dtype: int64

# %%
df[['Agency Type','City']].value_counts().sort_values(ascending=False)
# Out:
# Agency Type       City
# Municipal Police  Los Angeles    38907
#                   New York       38416
#                   Cook           22279
#                   Wayne          19321
#                   Harris         13634
#                                  ...
# Sheriff           Rawlins            1
#                   Red Lake           1
# Municipal Police  Renville           1
# Sheriff           Trigg              1
# Municipal Police  Winneshiek         1
# Length: 3946, dtype: int64

# %%
df[['City','Agency Type']].value_counts().sort_values(ascending=False)
# Out:
# City            Agency Type
# Los Angeles     Municipal Police    38907
# New York        Municipal Police    38416
# Cook            Municipal Police    22279
# Wayne           Municipal Police    19321
# Harris          Municipal Police    13634
#                                     ...
# San Bernardino  State Police            1
# Chariton        Sheriff                 1
# Kanawha         Special Police          1
# Alleghany       State Police            1
# Hendry          Tribal Police           1
# Length: 3946, dtype: int64

# %% [markdown]
# **2. De los tipos de agencia, determinar las de tipo Sheriff y mostrar el nombre.**

# %%
df[['Agency Name','Agency Type']]
# Out:
#             Agency Name       Agency Type
# 0             Anchorage  Municipal Police
# 1             Anchorage  Municipal Police
# 2             Anchorage  Municipal Police
# 3             Anchorage  Municipal Police
# 4             Anchorage  Municipal Police
# ...                 ...               ...
# 638449      Park County           Sheriff
# 638450  Sheridan County           Sheriff
# 638451         Sheridan  Municipal Police
# 638452  Sublette County           Sheriff
# 638453     Rock Springs  Municipal Police
#
# [638454 rows x 2 columns]

# %%
df[df['Agency Type']=='Sheriff']
# Out:
#         Record ID Agency Code      Agency Name Agency Type       City  \
# 47             48     AL00100        Jefferson     Sheriff  Jefferson
# 48             49     AL00100        Jefferson     Sheriff  Jefferson
# 49             50     AL00100        Jefferson     Sheriff  Jefferson
# 50             51     AL00100        Jefferson     Sheriff  Jefferson
# 51             52     AL00100        Jefferson     Sheriff  Jefferson
# ...           ...         ...              ...         ...        ...
# 638445     638446     WY01200   Lincoln County     Sheriff    Lincoln
# 638446     638447     WY01300   Natrona County     Sheriff    Natrona
# 638449     638450     WY01500      Park County     Sheriff       Park
# 638450     638451     WY01700  Sheridan County     Sheriff   Sheridan
# 638452     638453     WY01800  Sublette County     Sheriff   Sublette
#
#           State  Year      Month  Incident              Crime Type  ...  \
# ...

# %% [markdown]
# **3. Listar los estados más afectados por crímenes perpetrados por mujeres.**

# %%
df[['State','Perpetrator Sex']] #Estados y sexo predadores.
# Out:
#           State Perpetrator Sex
# 0        Alaska            Male
# 1        Alaska            Male
# 2        Alaska         Unknown
# 3        Alaska            Male
# 4        Alaska         Unknown
# ...         ...             ...
# 638449  Wyoming         Unknown
# 638450  Wyoming            Male
# 638451  Wyoming          Female
# 638452  Wyoming            Male
# 638453  Wyoming          Female
#
# [638454 rows x 2 columns]

# %%
df[df['Perpetrator Sex']=='Female'] #Predadores femenimos
# Out:
#         Record ID Agency Code               Agency Name       Agency Type  \
# 15             16     AK00101                 Anchorage  Municipal Police
# 27             28     AKASP00       Alaska State Police      State Police
# 28             29     AKASP00       Alaska State Police      State Police
# 46             47     AKASP00       Alaska State Police      State Police
# 48             49     AL00100                 Jefferson           Sheriff
# ...           ...         ...                       ...               ...
# 638433     638434     WVWSP53  State Police: Upperglade      State Police
# 638434     638435     WVWSP55       State Police: Welch      State Police
# 638435     638436     WVWSP55       State Police: Welch      State Police
# 638451     638452     WY01701                  Sheridan  Municipal Police
# 638453     638454     WY01902              Rock Springs  Municipal Police
#
#               City          State  Year      Month  Incident  \
# ...

# %% [markdown]
# **4. Listar los estados más afectados por crímenes perpetrados por hombres.**

# %%
df[df['Perpetrator Sex']=='Male']#Predadores masculinos.
# Out:
#         Record ID Agency Code      Agency Name       Agency Type       City  \
# 0               1     AK00101        Anchorage  Municipal Police  Anchorage
# 1               2     AK00101        Anchorage  Municipal Police  Anchorage
# 3               4     AK00101        Anchorage  Municipal Police  Anchorage
# 5               6     AK00101        Anchorage  Municipal Police  Anchorage
# 6               7     AK00101        Anchorage  Municipal Police  Anchorage
# ...           ...         ...              ...               ...        ...
# 638446     638447     WY01300   Natrona County           Sheriff    Natrona
# 638447     638448     WY01301           Casper  Municipal Police    Natrona
# 638448     638449     WY01301           Casper  Municipal Police    Natrona
# 638450     638451     WY01700  Sheridan County           Sheriff   Sheridan
# 638452     638453     WY01800  Sublette County           Sheriff   Sublette
#
# ...

# %% [markdown]
# **5. Determinar el número exacto de crímenes hechos por mujeres de raza Asian/Pacific Islander.**

# %%
df[df['Perpetrator Race']=='Asian/Pacific Islander']#Perpetradores Asian/Pacific Islander
# Out:
#         Record ID Agency Code          Agency Name       Agency Type  \
# 31             32     AKASP00  Alaska State Police      State Police
# 772           773     AR07501           Dardanelle  Municipal Police
# 1315         1316     CA00800            Del Norte           Sheriff
# 1554         1555     CA01503               Delano  Municipal Police
# 1569         1570     CA01801           Susanville  Municipal Police
# ...           ...         ...                  ...               ...
# 638191     638192     WASPD00              Seattle  Municipal Police
# 638274     638275     WIMPD00            Milwaukee  Municipal Police
# 638282     638283     WIMPD00            Milwaukee  Municipal Police
# 638322     638323     WIMPD00            Milwaukee  Municipal Police
# 638451     638452     WY01701             Sheridan  Municipal Police
#
#              City       State  Year      Month  Incident  \
# 31         Juneau      Alaska  1980       June         1
# ...

# %% [markdown]
# **6. Determinar la raza más criminal.**

# %%
df['Perpetrator Race'].value_counts().sort_values(ascending=False) #Raza más criminal
# Out:
# White                            218243
# Black                            214516
# Unknown                          196047
# Asian/Pacific Islander             6046
# Native American/Alaska Native      3602
# Name: Perpetrator Race, dtype: int64

# %% [markdown]
# **7. Determinar el número exacto de hispanos que han asesinado mediante la estrangulación.**

# %%
df[df['Perpetrator Ethnicity']=='Hispanic'].value_counts()
# Out:
# Record ID  Agency Code  Agency Name     Agency Type       City         State       Year  Month     Incident  Crime Type              Crime Solved  Victim Sex  Victim Age  Victim Race  Victim Ethnicity  Perpetrator Sex  Perpetrator Age  Perpetrator Race  Perpetrator Ethnicity  Relationship  Weapon        Victim Count  Perpetrator Count  Record Source
# 142        AL00102      Birmingham      Municipal Police  Jefferson    Alabama     1980  October   4         Murder or Manslaughter  Yes           Male        19          Black        Not Hispanic      Male             25               Black             Hispanic               Acquaintance  Handgun       0             0                  FBI              1
# ...

# %%
df[['Perpetrator Ethnicity','Crime Type']].value_counts().sort_values(ascending=False) #Raza más criminal
# Out:
# Perpetrator Ethnicity  Crime Type
# Unknown                Murder or Manslaughter        440814
# Not Hispanic           Murder or Manslaughter        142354
# Hispanic               Murder or Manslaughter         46170
# Unknown                Manslaughter by Negligence      5596
# Not Hispanic           Manslaughter by Negligence      2818
# Hispanic               Manslaughter by Negligence       702
# dtype: int64

# %%
df['Perpetrator Race'].value_counts().sort_values(ascending=False) #Raza más criminal
# Out:
# White                            218243
# Black                            214516
# Unknown                          196047
# Asian/Pacific Islander             6046
# Native American/Alaska Native      3602
# Name: Perpetrator Race, dtype: int64

# %% [markdown]
# **8. Determinar el tipo de relación más peligrosa, el cual comete más homicidios con armas de tipo Shotgun=escopeta.**

# %%
df[['Relationship','Weapon']] #Relación y armas en el suceso.
# Out:
#         Relationship         Weapon
# 0       Acquaintance   Blunt Object
# 1       Acquaintance  Strangulation
# 2            Unknown        Unknown
# 3       Acquaintance  Strangulation
# 4            Unknown        Unknown
# ...              ...            ...
# 638449       Unknown        Handgun
# 638450  Acquaintance        Handgun
# 638451      Daughter    Suffocation
# 638452      Stranger          Knife
# 638453      Daughter   Blunt Object
#
# [638454 rows x 2 columns]

# %%
df[df['Weapon']=='Shotgun']
# Out:
#         Record ID Agency Code            Agency Name       Agency Type  \
# 11             12     AK00101              Anchorage  Municipal Police
# 29             30     AKASP00    Alaska State Police      State Police
# 48             49     AL00100              Jefferson           Sheriff
# 60             61     AL00100              Jefferson           Sheriff
# 67             68     AL00101               Bessemer  Municipal Police
# ...           ...         ...                    ...               ...
# 638196     638197     WI00300          Barron County           Sheriff
# 638220     638221     WI01801             Eau Claire  Municipal Police
# 638411     638412     WV03400        Nicholas County           Sheriff
# 638423     638424     WVWSP01  State Police: Beckley      State Police
# 638442     638443     WY01100         Laramie County           Sheriff
#
#               City          State  Year      Month  Incident  \
# ...

# %% [markdown]
# **9. ¿Cuál es el sexo de quienes más homicidios han cometido con Veneno =Poison.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638454 entries, 0 to 638453
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Record ID              638454 non-null  int64
#  1   Agency Code            638454 non-null  object
#  2   Agency Name            638454 non-null  object
#  3   Agency Type            638454 non-null  object
#  4   City                   638454 non-null  object
#  5   State                  638454 non-null  object
#  6   Year                   638454 non-null  int64
#  7   Month                  638454 non-null  object
#  8   Incident               638454 non-null  int64
#  9   Crime Type             638454 non-null  object
#  10  Crime Solved           638454 non-null  object
#  11  Victim Sex             638454 non-null  object
#  12  Victim Age             638454 non-null  int64
#  13  Victim Race            638454 non-null  object
# ...

# %%
df[df['Weapon']=='Poison']
# Out:
#         Record ID Agency Code                 Agency Name       Agency Type  \
# 2950         2951     CA01942                 Los Angeles  Municipal Police
# 4072         4073     CA03711                   San Diego  Municipal Police
# 7208         7209     GAAPD00                     Atlanta  Municipal Police
# 8268         8269     ILCPD00                     Chicago  Municipal Police
# 9354         9355     KY026SP   State Police: Clay County      State Police
# ...           ...         ...                         ...               ...
# 634694     634695     OK07300              Wagoner County           Sheriff
# 634695     634696     OK07300              Wagoner County           Sheriff
# 635073     635074     PA064SP  State Police: Wayne County      State Police
# 637636     637637     VA00800              Augusta County           Sheriff
# 638063     638064     WA01800               Kitsap County           Sheriff
#
# ...

# %%
df[['Perpetrator Race','Weapon']]
# Out:
#                      Perpetrator Race         Weapon
# 0       Native American/Alaska Native   Blunt Object
# 1                               White  Strangulation
# 2                             Unknown        Unknown
# 3                               White  Strangulation
# 4                             Unknown        Unknown
# ...                               ...            ...
# 638449                        Unknown        Handgun
# 638450                          White        Handgun
# 638451         Asian/Pacific Islander    Suffocation
# 638452                          White          Knife
# 638453                          White   Blunt Object
#
# [638454 rows x 2 columns]

# %% [markdown]
# **10. ¿Cuántos asesinos de raza negra atrapó el FBI?**

# %%
df[df['Perpetrator Race']=='Black'].count()
# Out:
# Record ID                1575
# Agency Code              1575
# Agency Name              1575
# Agency Type              1575
# City                     1575
# State                    1575
# Year                     1575
# Month                    1575
# Incident                 1575
# Crime Type               1575
# Crime Solved             1575
# Victim Sex               1575
# Victim Age               1575
# Victim Race              1575
# Victim Ethnicity         1575
# Perpetrator Sex          1575
# Perpetrator Age          1575
# Perpetrator Race         1575
# Perpetrator Ethnicity    1575
# Relationship             1575
# Weapon                   1575
# Victim Count             1575
# Perpetrator Count        1575
# Record Source            1575
# dtype: int64

# %% [markdown]
# **11. ¿Cuántas victimas de tipo hispanas han muerto y por cual tipo de medio (arma blanca, arma de fuego, etc).**

# %%
df['Weapon'].unique()
df['Victim Ethnicity']=='Hispanic'
df.groupby(['Victim Ethnicity', 'Weapon'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5897    False
# 5898     True
# 5899     True
# 5900    False
# 5901    False
# Name: Victim Ethnicity, Length: 5902, dtype: bool

# %% [markdown]
# **12. ¿Cuál ha sido el asesino más viejo?**

# %%
df['Perpetrator Age'].max()

# %% [markdown]
# **13. ¿Cuál ha sido el asesino más jóven?**

# %%
df['Perpetrator Age'].min()

# %% [markdown]
# **14. ¿Cuál es el total de homicidios desde el año 1995 hasta el año 2000 (ADVERTENCIA: META CONSULTAS DE TIPO KILLER)?**

# %%
df[(df['Year']>=1995) & (df['Year']<=2000)]

# %% [markdown]
# **15. ¿Cuál es el total de homicidiosdesde el año 1995 hasta el año 2000 perpetrados por hombres de raza negra por sofocación=suffocation?**

# %%
df[(df['Year']>=1995) & (df['Year']=<2000) & (df['Weapon']=='Suffocation') & (df['Perpetrator Race']=='Black')]

# %% [markdown]
# **16. Determinar los homicidios anteriores a 1980 perpetrados por hombres del estado de Alaska de raza negra.**

# %%
df_year = df[df["Year"]<=1980]
df_year[(df_year["Perpetrator Race"]=="Black")&(df_year['Perpetrator Sex']=='Male')&(df_year["State"]=="Alaska")]

# %% [markdown]
# **17. Determinar los homicidios de la policia municipal de la ciudad de New York los cuales hayan sido por relaciones de tipo Ex-Wife y, además, que su modo haya sido Estrangulación=Strangulation.**

# %%
df[(df['Agency Type']=='Municipal Police') & (df['City']=='New York') & (df['Relationship']=='Ex-Wife')&(df['Weapon']=='Strangulation')]

# %% [markdown]
# **18. Listar todos los homicidios que hayan ocurrido desde 1980 hasta 1970 en el estado de Illinois de los cuales el grupo étnico de la víctima no es hispano= Not Hispanic y la relación con el asesino fue de amigos=Friends y el arma utilizada fue una escopeta=Shotgun.**

# %%
df[(df['Year']>=1995) & (df['Year']<=2000) & (df['Victim Ethnicity']=='Not Hispanic') & (df['Weapon']=='Shotgun') & (df['Relationship']=='Friends')]
